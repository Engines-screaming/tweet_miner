# %% [markdown]
# Exploration of Tweets about wireless carriers

# %%
import sqlite3
import pandas as pd
import seaborn as sns

# import data
conn = sqlite3.connect('../data/wireless.db')
sql = 'select * from tweets'
df = pd.read_sql(sql, conn)
df.head()
# Out:
#    category  sentiment_score
# 0  @TMobile            0.000
# 1  @TMobile            0.625
# 2  @TMobile            0.600
# 3  @TMobile            0.500
# 4  @TMobile            0.000

# %%
# show how many tweets were collected for each carrier
counts = df.groupby("category").count()
counts
# Out:
#           sentiment_score
# category
# @ATT                  224
# @TMobile             1953
# @Verizon              207

# %% [markdown]
# TMobile is doing a sweepstakes right now, so there are a lot of tweets @ Tmo right now.

# %%
sns.boxplot(data=df, x='category', y='sentiment_score')
